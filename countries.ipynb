# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the provided World Bank population dataset
file_path = "API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv"
df = pd.read_csv(file_path, skiprows=4)
# Choose the year to visualize
year = "2024"

# Drop rows with missing population data
df_cleaned = df[["Country Name", year]].dropna()

# Sort and select top 20 countries by population
top_countries = df_cleaned.sort_values(by=year, ascending=False).head(20)

# %%
# Plot bar chart
plt.figure(figsize=(12, 8))
plt.barh(top_countries["Country Name"], top_countries[year], color='skyblue')
plt.xlabel("Population")
plt.title(f"Top 20 Countries by Population in {year}")
plt.gca().invert_yaxis()  # Show highest population at top
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
